# %%
x_field = 'x'
y_field = 'y'
table_filename = r'C:\Users\dwmcclellan\OneDrive - Fort Lewis College\0-Fall 2021\GEOG-315\Lab-12\data\track2.csv'
plot_filename = r'C:\Users\dwmcclellan\OneDrive - Fort Lewis College\0-Fall 2021\GEOG-315\Lab-12\data\problem1.png'

# %%
# CHANGE THIS TO POINT TO YOUR WEEK 12 DATA FOLDER.
data_folder = r'C:\Users\dwmcclellan\OneDrive - Fort Lewis College\0-Fall 2021\GEOG-315\Lab-12\data'

# %%
import os
import matplotlib.pyplot as plt
import arcpy

# Change the Python working directory.
os.chdir(data_folder)

# Set up matplotlib to draw in the notebook.
# %matplotlib inline

# %%
# Read the data from the shapefile.
x, y = zip(*arcpy.da.SearchCursor(table_filename, [x_field, y_field]))   

# Plot the data.
plt.plot(x, y, 'o')

# Add titles.
plt.title('Problem 1')

# Save the figure as a PNG with a transparent background.
plt.savefig(plot_filename, transparent=True)
